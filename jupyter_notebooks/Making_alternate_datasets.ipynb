# %% [markdown]
# # Making Alternate Datasets
# - After training/test sets have been extracted using train.py, it might be necessary to build alternate datasets if data other than hours played are to be used in ML experiments
# - By reading in the datasets and using the IDs, we can get corresponding data in the Mongo database

# %%
from util.mongodb import connect_to_db
from src.features import normalize_id
from collections import Counter
from json import loads

# %%
# Connect to Mongo DB
port = 27017
reviewdb = connect_to_db(port)

# %%
! ls -lh ../working/*jsonlines
# Out:
# -rw-rw-r-- 1 mulhollm mulhollm 187M Sep 14 03:41 ../working/Arma_3.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 116M Sep 14 03:38 ../working/Arma_3.test.jsonlines
# -rw-rw-r-- 1 mulhollm mulhollm 161M Sep 14 03:41 ../working/Counter_Strike_Global_Offensive.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 104M Sep 14 03:38 ../working/Counter_Strike_Global_Offensive.test.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 2.0G Sep 14 03:44 ../working/Counter_Strike.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 148M Sep 14 03:39 ../working/Counter_Strike.test.jsonlines
# -rw-rw-r-- 1 mulhollm mulhollm 161M Sep 14 03:44 ../working/Dota_2.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 170M Sep 14 03:39 ../working/Dota_2.test.jsonlines
# -rw-rw-r-- 1 mulhollm mulhollm 169M Sep 14 03:45 ../working/Garrys_Mod.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 181M Sep 14 03:39 ../working/Garrys_Mod.test.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 172M Sep 14 03:45 ../working/Grand_Theft_Auto_V.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 109M Sep 14 03:39 ../working/Grand_Theft_Auto_V.test.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 181M Sep 14 03:45 ../working/Sid_Meiers_Civilization_5.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 113M Sep 14 03:40 ../working/Sid_Meiers_Civilization_5.test.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 164M Sep 14 03:46 ../working/Team_Fortress_2.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm  93M Sep 14 03:40 ../working/Team_Fortress_2.test.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 171M Sep 14 03:46 ../working/The_Elder_Scrolls_V.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 112M Sep 14 03:40 ../working/The_Elder_Scrolls_V.test.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 171M Sep 14 03:46 ../working/Warframe.jsonlines
# -rw-r--r-- 1 mulhollm mulhollm 125M Sep 14 03:40 ../working/Warframe.test.jsonlines

# %%
# Let's work with the data in a relatively small dataset, the test set for
# Team Fortress 2
data = [loads(line) for line in open('../working/Team_Fortress_2.test.jsonlines')]

# %%
data[0].keys()
# Out:
# dict_keys(['id', 'y', 'x'])

# %%
len(data)
# Out:
# 1550

# %%
normalized_ids_counter = Counter([_data['id'] for _data in data])

# %%
duplicates = [_id for _id in normalized_ids_counter if normalized_ids_counter[_id] > 1]

# %%
duplicate_1_id = duplicates[0]
duplicate_1_id
# Out:
# '5889414799363945755'

# %%
duplicate_1 = [_data for _data in data if _data['id'] == duplicate_1_id]

# %%
duplicate_1[0] == duplicate_1[1]
# Out:
# True

# %%
normalized_ids_data_dict = {}
for _data in data:
    _id = _data['id']
    # Don't add an entry if this sample's ID is already accounted for
    if _id in normalized_ids_data_dict.keys():
        continue
    normalized_ids_data_dict[_id] = {'data': _data,
                                     'db_data': None}

# %%
list(normalized_ids_data_dict.keys())[:5]
# Out:
# ['4791911353521639065',
#  '5927141028353036122',
#  '5348493173370030504',
#  '7500891916612766495',
#  '4438889256055680651']

# %%
normalized_ids_data_dict['4791911353521639065']
# Out:
# {'data': {'id': '4791911353521639065',
#   'x': {'chips ,': 1,
#    'invisible': 1,
#    'up': 1,
#    'ts sa': 1,
#    'uses': 1,
#    'arn': 1,
#    'snip': 1,
#    'GO ': 1,
#    'destroy these': 1,
#    'at st': 1,
#    'mos': 1,
#    'do:ROOT:do': 1,
#    'the bubbles': 1,
#    'shot in': 1,
#    'ORE t': 1,
#    'plain': 1,
#    'like trading': 1,
#    '! If': 1,
#    'well ': 1,
#    ' is A': 1,
#    ' get ': 1,
#    'in b': 1,
#    's int': 1,
#    's g': 1,
#    'uced': 1,
#    'brothers cartoons': 1,
#    'and valuable': 1,
#    'ed, c': 1,
#    'n Ba': 1,
#    'd FP': 1,
#    'ust ': 1,
#    "people 's": 1,
#    'T imp': 1,
#    'an ge': 1,
#    "'s cartoonesque": 1,
#    ' e': 1,
#    'to backstab': 1,
#    'intutwine': 1,
#    'o by ': 1,
#    'hat s': 1,
#    '~10/10': 1,
#    'to stop': 1,
#    '10/': 1,
#    'is enough': 1,
#    'when this': 1,
#    'ay to': 1,
#    'her': 1,
#    'hin': 1,
#    '.... but': 1,
#    'shooters ,': 1,
#    'miniguns': 1,
#    'break the': 1,
#    'tr': 1,
#    'if:VMOD:have': 1,
#    'eamwo': 1,
#    'upgrade his': 1,
#    'played': 1,
#    'rarely': 1,
#    'sugar ,': 1,
#    'makes you': 1,
#    'ngs d': 1,
#    'uses his': 1,
#    'thi': 1,
#    'e f': 1,
#    'fe': 1,
#    'while now': 1,
#    'be:ROOT:if': 1,
#    'has fancy': 1,
#    'no now': 1,
#    ' 10': 1,
#    'meter': 1,
#    '2 an': 1,
#    'started on': 1,
#    's no ': 1,
#    'i join': 1,
#    'rbly': 1,
#    'fortress 2': 1,
#    'that all': 1,
#    'THOUG': 1,
#    'GO': 1,
#    'with flamthrowers': 1,
#    'who ': 1,
#    ' opti': 1,
#    'THI': 1,
#    'vid': 1,
#    'side ,': 1,
#    ' u': 1,
#    ' spy ': 1,
#    'E TH': 1,
#    'the batter': 1,
#    'ent p': 1,
#    'e t': 1,
#    ', being': 1,
#    'son ': 1,
#    'heat': 1,
#    'gloriously': 1,
#    'ames': 1,
#    'give': 1,
#    'cluster477': 1,
#    'upgraded to': 1,
#    'cluster77': 1,
#    'it b': 1,
#    'shovel )': 1,
#    'Don': 1,
#    'it has': 1,
#    'pu': 1,
#    'te': 1,
#    'at t': 1,
#    'match .': 1,
#    'is better.the': 1,
#    'ne w': 1,
#    'compu': 1,
#    ' f': 1,
#    'illed': 1,
#    'handle out': 1,
#    'ground nutmeg': 1,
#    'behind !': 1,
#    'in strategy': 1,
#    'with nice': 1,
#    'the head': 1,
#    'unsalted butter': 1,
#    'sappers': 1,
#    'ame. ': 1,
#    'anot': 1,
#    'my money': 1,
#    'because unlike': 1,
#    'cluster7402': 1,
#    'ted ': 1,
#    'love of': 1,
#    'and e': 1,
#    'get c': 1,
#    'me t': 1,
#    'ats. ': 1,
#    'ain': 1,
#    'keep playing': 1,
#    'tt': 1,
#    'thick': 1,
#    '~sleep ?': 1,
#    'can g': 1,
#    'huddah': 1,
#    'consi': 1,
#    'realistic ,': 1,
#    'du': 1,
#    "'s sentry": 1,
#    'a sticky': 1,
#    'as ha': 1,
#    'they try': 1,
#    "ca n't": 1,
#    'not your': 1,
#    'beam towards': 1,
#    't go ': 1,
#    'is not': 1,
#    'fir': 1,
#    'MOST': 1,
#    'erfor': 1,
#    'dicti': 1,
#    'shovel': 1,
#    'ponder': 1,
#    'cluster15994': 1,
#    '10x': 1,
#    'silly': 1,
#    'or m': 1,
#    'flame thrower': 1,
#    'another of': 1,
#    'forevah !': 1,
#    'which:NMOD:be': 1,
#    'bod': 1,
#    ', sugar': 1,
#    'PLE': 1,
#    'spawn': 1,
#    'bac': 1,
#    '0/10': 1,
#    'flamthrowers ,': 1,
#    'aspec': 1,
#    'se': 1,
#    'ause ': 1,
#    'sentry guns': 1,
#    'ody i': 1,
#    'addicting': 1,
#    'wolf in': 1,
#    'normal sentry': 1,
#    'get': 1,
#    ' THIS': 1,
#    ' watc': 1,
#    ' con': 1,
#    'stay interested': 1,
#    'ck in': 1,
#    ' m': 1,
#    ' of': 1,
#    'e. I': 1,
#    'panache': 1,
#    'r gi': 1,
#    'ever ,': 1,
#    'i now': 1,
#    'ave p': 1,
#    'skillet': 1,
#    'the milk': 1,
#    'understand and': 1,
#    ' I w': 1,
#    ') A': 1,
#    'nickel': 1,
#    ' of p': 1,
#    'bowl': 1,
#    'or just': 1,
#    'i was': 1,
#    'ing': 1,
#    'and if': 1,
#    'gameplay is': 1,
#    'i love': 1,
#    'tf2 forevah': 1,
#    ' si': 1,
#    'just.': 1,
#    'enemy engineer': 1,
#    "that 's": 1,
#    'com': 1,
#    ' PLE': 1,
#    ', ': 1,
#    'uses a': 1,
#    'salt': 1,
#    'e, an': 1,
#    'ked b': 1,
#    '2 a': 1,
#    ' GI': 1,
#    've ev': 1,
#    'role in': 1,
#    'ts at': 1,
#    'dramatic': 1,
#    '. as': 1,
#    'f yo': 1,
#    'IC ': 1,
#    '! this': 1,
#    ' of V': 1,
#    'on w': 1,
#    'ack ': 1,
#    'receive (': 1,
#    'ect. ': 1,
#    's for': 1,
#    'rmi': 1,
#    'adding fruit': 1,
#    'packed game': 1,
#    'go though': 1,
#    'giant': 1,
#    'cluster458': 1,
#    'in 2012': 1,
#    'most part': 1,
#    'as it': 1,
#    'choose from': 1,
#    'e wo': 1,
#    'game overall': 1,
#    'ost c': 1,
#    'accent': 1,
#    'o P': 1,
#    'than ': 1,
#    'with constant': 1,
#    '12': 1,
#    'at': 1,
#    'accent while': 1,
#    'never ending': 1,
#    'from headshots': 1,
#    '2012 and': 1,
#    ', hats': 1,
#    ' ONE!': 1,
#    'me st': 1,
#    'imi': 1,
#    'the richest': 1,
#    'r m': 1,
#    'Bat': 1,
#    "trolling di'cks": 1,
#    'cyclops .': 1,
#    'get extra': 1,
#    'snap people': 1,
#    "little bi'tches": 1,
#    'game the': 1,
#    'in another': 1,
#    'vably': 1,
#    'LMO': 1,
#    'need an': 1,
#    'zeroes_repvecs': 11,
#    'ngs ': 1,
#    'LEA': 1,
#    'is': 1,
#    'pushing': 1,
#    'complex:PRD:and': 1,
#    'whisk': 1,
#    ':3': 1,
#    'ME A': 1,
#    'ced g': 1,
#    'ng ': 1,
#    'ck': 1,
#    ', in-depth': 1,
#    'and allow': 1,
#    'absolutely': 1,
#    'do:ROOT:go': 1,
#    'at room': 1,
#    ' fu': 1,
#    'make your': 1,
#    'l.': 1,
#    'the match': 1,
#    'some fun': 1,
#    'y ': 1,
#    'is as': 1,
#    'leave': 1,
#    'ser': 1,
#    'be removed': 1,
#    'dealing ,': 1,
#    'cover': 1,
#    'with sliced': 1,
#    '. I ': 1,
#    ' A ': 1,
#    ' Ba': 1,
#    '. a': 1,
#    '$ 400000': 1,
#    'r a': 1,
#    'other experiences': 1,
#    ' in 2': 1,
#    'it go': 1,
#    's in': 1,
#    'attle': 1,
#    'e ga': 1,
#    'stab': 1,
#    "'re good": 1,
#    'funny': 1,
#    'ld ': 1,
#    'spec': 1,
#    "he 'll": 1,
#    'ast l': 1,
#    'sniper': 1,
#    'kill all': 1,
#    'to lone': 1,
#    ' play': 1,
#    'status': 1,
#    'anywho': 1,
#    'spines with': 1,
#    ', scottish': 1,
#    'expect a': 1,
#    'machete': 1,
#    'll. A': 1,
#    'down sights': 1,
#    ', whisk': 1,
#    'collect': 1,
#    'd to ': 1,
#    'here in': 1,
#    'experience:OBJ:on': 1,
#    'general gameplay': 1,
#    'is awesome': 1,
#    "sh'itty community": 1,
#    'damage': 1,
#    'IVE T': 1,
#    'Win a': 1,
#    ', do': 1,
#    'and you': 1,
#    'now you': 1,
#    'quickscopes': 1,
#    'a smg': 1,
#    'MED': 1,
#    'spy': 1,
#    'another bowl': 1,
#    'plz': 1,
#    'wel': 1,
#    'nd ge': 1,
#    'd..': 1,
#    'snipe': 1,
#    'flip': 1,
#    'spatula': 1,
#    'his teammates': 1,
#    ' aga': 1,
#    'u do': 1,
#    'created with': 1,
#    ' MOR': 1,
#    'deos ': 1,
#    'care to': 1,
#    'the guns': 1,
#    '... with': 1,
#    'and its': 1,
#    'making no': 1,
#    '. give': 1,
#    'this meter': 1,
#    'exciting': 1,
#    'cs:go ,': 1,
#    'e pa': 1,
#    ' eve': 1,
#    'et cr': 1,
#    'launcher ,': 1,
#    'e whi': 1,
#    's so': 1,
#    'ess ': 1,
#    'or 2': 1,
#    'uc': 1,
#    '..': 1,
#    'n t': 1,
#    'su': 1,
#    'little praise': 1,
#    'evab': 1,
#    'strange person': 1,
#    'game on': 1,
#    'cori': 1,
#    'hat ': 1,
#    'is friendly': 1,
#    'things': 1,
#    'ddic': 1,
#    "'ll go": 1,
#    'when you': 1,
#    'new level': 1,
#    'been created': 1,
#    'cr': 1,
#    'nce o': 1,
#    '=edit= hey': 1,
#    'expansive trading': 1,
#    ' by w': 1,
#    'o Win': 1,
#    'EDIC': 1,
#    'play the': 1,
#    '. furthermore': 1,
#    'of what': 1,
#    'this ': 1,
#    ' vide': 1,
#    'iste': 1,
#    'truly ,': 1,
#    'looked back': 1,
#    'nd ev': 1,
#    '" watch': 1,
#    'ull  ': 1,
#    'ced ': 1,
#    ', protesting': 1,
#    'od': 1,
#    'cod': 1,
#    'rm': 1,
#    'a entrenching': 1,
#    'of old': 1,
#    'ay of': 1,
#    'but used': 1,
#    'there is': 1,
#    ', unbelievably': 1,
#    'turns into': 1,
#    ' com': 1,
#    'played and': 1,
#    'a': 1,
#    'controls': 1,
#    '? of': 1,
#    'and never': 1,
#    'damage dealers': 1,
#    ' int': 1,
#    'apart': 1,
#    'to come': 1,
#    'man vs.': 1,
#    '01': 1,
#    'played this': 1,
#    'o sni': 1,
#    'us ': 1,
#    'me wh': 1,
#    'that:VMOD:go': 1,
#    'uh': 1,
#    'lso': 1,
#    'game to': 1,
#    'outfit that': 1,
#    'x at ': 1,
#    ' go': 1,
#    'head': 1,
#    'loo': 1,
#    'has the': 1,
#    'y bal': 1,
#    'entr': 1,
#    'n c': 1,
#    'he g': 1,
#    'climb': 1,
#    'comm': 1,
#    '. "': 1,
#    'heart ,': 1,
#    'owd': 1,
#    ' has': 1,
#    'learn:VMOD:at': 1,
#    ', ladle': 1,
#    'wolf:PMOD:lone': 1,
#    'ing i': 1,
#    'give:VMOD:go': 1,
#    'sex': 1,
#    'caus': 1,
#    'pc modern': 1,
#    'ats': 1,
#    'then whisk': 1,
#    ' Win ': 1,
#    'n who': 1,
#    'jumping ,': 1,
#    'pan': 1,
#    'fun !': 1,
#    'battlefield': 1,
#    'usly ': 1,
#    'team based': 1,
#    'is o': 1,
#    'soo': 1,
#    'until bubbles': 1,
#    'us': 1,
#    'pay -': 1,
#    '. A ': 1,
#    'nd s': 1,
#    'r on ': 1,
#    'aimbot': 1,
#    'and they': 1,
#    'instead': 1,
#    'bored': 1,
#    'punch people': 1,
#    'fun and': 1,
#    'po': 1,
#    'leas': 1,
#    'cluster14826': 1,
#    'have one': 1,
#    'hi': 1,
#    ', gun': 1,
#    'as h': 1,
#    'can pick': 1,
#    ' le': 1,
#    'games i': 1,
#    'ick': 1,
#    'eggs': 1,
#    'liev': 1,
#    'an': 1,
#    'over-powered .': 1,
#    '.': 1,
#    'intro': 1,
#    "e's p": 1,
#    'EASE ': 1,
#    'modes': 1,
#    ' seri': 1,
#    'needed now': 1,
#    'have dramatic': 1,
#    'annoying people': 1,
#    'ked': 1,
#    'little': 1,
#    '9/10': 1,
#    '2 he': 1,
#    'ull': 1,
#    'target the': 1,
#    ' up ': 1,
#    'e. E': 1,
#    'help ,': 1,
#    'one over-powered': 1,
#    'if your': 1,
#    'great range': 1,
#    'dealers in': 1,
#    'E T': 1,
#    'loy': 1,
#    'and silly': 1,
#    'although the': 1,
#    "'s like": 1,
#    'enemy when': 1,
#    'different things': 1,
#    'fect': 1,
#    'shop for': 1,
#    'son w': 1,
#    'tf2 is': 1,
#    'oked ': 1,
#    'light': 1,
#    '/10 :': 1,
#    'game ': 1,
#    'nbeli': 1,
#    'character': 1,
#    'S GA': 1,
#    'agai': 1,
#    'annoyed by': 1,
#    'ink': 1,
#    'addicting with': 1,
#    'bubbles': 1,
#    'i ma': 1,
#    'even just': 1,
#    'good idea': 1,
#    '$ money': 1,
#    'that:NMOD:stab': 1,
#    '. make': 1,
#    'wierd outfit': 1,
#    'being careful': 1,
#    'ts a': 1,
#    'get:VC:get': 1,
#    'randomizer maps': 1,
#    'a beautifully': 1,
#    'scoring': 1,
#    ', co': 1,
#    'steam !': 1,
#    'ST im': 1,
#    '. the': 1,
#    'just hats': 1,
#    '.. d': 1,
#    'cool items': 1,
#    'than dota': 1,
#    's at': 1,
#    'come': 1,
#    'in general': 1,
#    'now': 1,
#    'adult !': 1,
#    'perf': 1,
#    'not have': 1,
#    'hoping to': 1,
#    ' a ': 1,
#    'the first': 1,
#    'rf': 1,
#    'game ,': 1,
#    'fun to': 1,
#    'solo': 1,
#    'n jus': 1,
#    'nd si': 1,
#    'more as': 1,
#    "game 's": 1,
#    'y ;': 1,
#    'spy....just..ju.just': 1,
#    'f th': 1,
#    'you can': 1,
#    'warner': 1,
#    ', level': 1,
#    'it is': 1,
#    'launcer': 1,
#    'boston': 1,
#    ' GO M': 1,
#    'do not': 1,
#    'sphee': 1,
#    'LEAS': 1,
#    'healing have': 1,
#    ' C': 1,
#    'updates': 1,
#    'jus': 1,
#    'also let': 1,
#    'ge': 1,
#    'team to': 1,
#    'no P': 1,
#    'classes': 1,
#    'you down': 1,
#    'has ': 1,
#    'ked ': 1,
#    'do by': 1,
#    'while reflecting': 1,
#    'tl': 1,
#    'sniper:OBJ:the': 1,
#    'or mo': 1,
#    'ST ': 1,
#    'f p': 1,
#    'grafics': 1,
#    'ised,': 1,
#    'd s': 1,
#    'myself': 1,
#    ' TF2': 1,
#    'i recommend': 1,
#    'pay you': 1,
#    'hacks ,': 1,
#    'crits .': 1,
#    ', a': 1,
#    'who are': 1,
#    'ES NO': 1,
#    ' at t': 1,
#    'comical': 1,
#    'cluster2538': 1,
#    'a defence': 1,
#    'the person': 1,
#    ' sim': 1,
#    'on co': 1,
#    'minigun': 1,
#    'wa': 1,
#    'phishers': 1,
#    'remaining': 1,
#    'with big': 1,
#    'with you': 1,
#    'healing': 1,
#    'in their': 1,
#    'ridiculus': 1,
#    'a main': 1,
#    ' D': 1,
#    'as another': 1,
#    'what ': 1,
#    'me. ': 1,
#    'the spy....just..ju.just': 1,
#    'ts. ': 1,
#    'mentioned': 1,
#    'hen I': 1,
#    'may be': 1,
#    'whisk together': 1,
#    'fight': 1,
#    'for adding': 1,
#    'just formed': 1,
#    'a p': 1,
#    'i can': 1,
#    's d': 1,
#    'allow you': 1,
#    'd get': 1,
#    'fect.': 1,
#    'arted': 1,
#    't com': 1,
#    'aus': 1,
#    'experience:OBJ:fps': 1,
#    '<': 1,
#    'win:NMOD:to': 1,
#    'tchi': 1,
#    'keeping': 1,
#    'unlike what': 1,
#    'the off': 1,
#    'in to': 1,
#    'remember to': 1,
#    'so simple': 1,
#    'h fun': 1,
#    'elaborate team': 1,
#    'fps experience': 1,
#    'play it': 1,
#    '... d': 1,
#    'well optimised': 1,
#    'Al': 1,
#    'recommend': 1,
#    't all': 1,
#    'taken over': 1,
#    ', you': 1,
#    'life before': 1,
#    ';) also': 1,
#    'pancake .': 1,
#    'e wol': 1,
#    'efor': 1,
#    'batter onto': 1,
#    'shame as': 1,
#    'they': 1,
#    'rockets ,': 1,
#    'can:VMOD:sniper': 1,
#    "n't p": 1,
#    'tress': 1,
#    'ed it': 1,
#    'anyone': 1,
#    'ng v': 1,
#    ' IF Y': 1,
#    'ruined social': 1,
#    ', when': 1,
#    'the back': 1,
#    'players be': 1,
#    'great free': 1,
#    'his/hers': 1,
#    'at:VMOD:and': 1,
#    '2 minutes': 1,
#    'adds to': 1,
#    'S ex': 1,
#    'ri': 1,
#    'niches': 1,
#    'nt': 1,
#    'thick batter': 1,
#    'wolfenstein': 1,
#    'ive': 1,
#    'a giant': 1,
#    'absolutely awesome': 1,
#    'too': 1,
#    'l. ': 1,
#    's sco': 1,
#    ' te': 1,
#    'nd': 1,
#    'hings': 1,
#    'sights ,': 1,
#    'and at': 1,
#    'sup': 1,
#    'as you': 1,
#    ' Even': 1,
#    'multiplayer .': 1,
#    'server !': 1,
#    'so m': 1,
#    'Do': 1,
#    'k ': 1,
#    'sa': 1,
#    'have never': 1,
#    'for a': 1,
#    'as:VMOD:be': 1,
#    'his/hers flame': 1,
#    ' thin': 1,
#    ', unb': 1,
#    'machine': 1,
#    'still not': 1,
#    'with your': 1,
#    ' me': 1,
#    'be': 1,
#    'instead he/she': 1,
#    'han j': 1,
#    'AL': 1,
#    'milk': 1,
#    'ch f': 1,
#    'rin': 1,
#    's do ': 1,
#    ' mo': 1,
#    'keeping the': 1,
#    'game:PMOD:balanced': 1,
#    'comme': 1,
#    'd si': 1,
#    'say:SBAR:be': 1,
#    'r pla': 1,
#    'MORE': 1,
#    'boots by': 1,
#    'and unreal': 1,
#    'ame a': 1,
#    'LE': 1,
#    'down .': 1,
#    'ONE!': 1,
#    'me is': 1,
#    ' MO': 1,
#    'cluster2442': 1,
#    've': 1,
#    'love': 1,
#    'cluster2917': 1,
#    'ayi': 1,
#    'kit': 1,
#    'since i': 1,
#    'etc .': 1,
#    ' pick': 1,
#    'is perfect': 1,
#    'complex at': 1,
#    'd on ': 1,
#    'target': 1,
#    'life .': 1,
#    'outs': 1,
#    'first weapons': 1,
#    'one of': 1,
#    'better.the action': 1,
#    'computer (': 1,
#    'outs ': 1,
#    'bye': 1,
#    'is M': 1,
#    'and ': 1,
#    'er c': 1,
#    's ha': 1,
#    'can:VMOD:pick': 1,
#    'cluster28522': 1,
#    'S N': 1,
#    ';) A': 1,
#    'ev': 1,
#    'to punch': 1,
#    'taunts': 1,
#    'put:VMOD:cod': 1,
#    'a electro-sapper': 1,
#    'R T': 1,
#    'axe .': 1,
#    's t': 1,
#    'simp': 1,
#    "'s pl": 1,
#    'years': 1,
#    'cluster250': 1,
#    'll ': 1,
#    'cor': 1,
#    't..': 1,
#    'le an': 1,
#    'met': 1,
#    'based': 1,
#    '10 :D': 1,
#    'the g': 1,
#    'complex': 1,
#    'medium heat': 1,
#    'standard fps': 1,
#    'sc': 1,
#    ' agai': 1,
#    ' much': 1,
#    'since': 1,
#    'camped': 1,
#    'group or': 1,
#    'than': 1,
#    'y wa': 1,
#    'fun!': 1,
#    'h fu': 1,
#    'eas': 1,
#    'and have': 1,
#    'e pla': 1,
#    'EAM ': 1,
#    'vulnerable': 1,
#    'ommen': 1,
#    '69/10': 1,
#    'meet': 1,
#    ' unl': 1,
#    ' g': 1,
#    'see people': 1,
#    ', that': 1,
#    'imple': 1,
#    's MO': 1,
#    'videos before': 1,
#    'nl': 1,
#    'nli': 1,
#    'stop ,': 1,
#    'cluster3705': 1,
#    ' pers': 1,
#    "n't aim": 1,
#    's I h': 1,
#    'procedure': 1,
#    ', randomizer': 1,
#    's had': 1,
#    'tabs': 1,
#    'your': 1,
#    'ou d': 1,
#    'n pi': 1,
#    'plus': 1,
#    ' Te': 1,
#    'of hilarious': 1,
#    'non-veterans can': 1,
#    "defense '": 1,
#    'be:VMOD:more': 1,
#    'are the': 1,
#    'PS ': 1,
#    'game.': 1,
#    't mos': 1,
#    'e any': 1,
#    'me i': 1,
#    ' scou': 1,
#    'anced': 1,
#    'main damage': 1,
#    'so s': 1,
#    "sh'itty": 1,
#    'ack,': 1,
#    ' as': 1,
#    'cluster818': 1,
#    'lve': 1,
#    'which gives': 1,
#    'on ...': 1,
#    'times .': 1,
#    'ay ': 1,
#    ', ju': 1,
#    'spend': 1,
#    'mostely': 1,
#    'do b': 1,
#    'back cause': 1,
#    'is highly': 1,
#    'is cs:go': 1,
#    'pt': 1,
#    'untill he': 1,
#    'loys ': 1,
#    'maps ,': 1,
#    'e se': 1,
#    'running': 1,
#    'untill': 1,
#    'have some': 1,
#    's mad': 1,
#    'perbl': 1,
#    't co': 1,
#    '3': 1,
#    'if': 1,
#    'who has': 1,
#    'ven ': 1,
#    'YOUR': 1,
#    'release a': 1,
#    '. then': 1,
#    'cluster30698': 1,
#    'yet ?': 1,
#    'get nearly': 1,
#    'at i': 1,
#    ' it ': 1,
#    ' :D': 1,
#    'complex:PRD:so': 1,
#    'e unl': 1,
#    'op ': 1,
#    'flip with': 1,
#    'heavies ~phlog': 1,
#    'cluster4': 1,
#    'are': 1,
#    'ict': 1,
#    'to get': 1,
#    'than other': 1,
#    'cluster2570': 1,
#    ' YOU': 1,
#    'other games': 1,
#    'me rage': 1,
#    'way i': 1,
#    '~it': 1,
#    'has so': 1,
#    'e to ': 1,
#    'be th': 1,
#    'say ': 1,
#    'got': 1,
#    'which': 1,
#    'and then': 1,
#    'well': 1,
#    'nlike': 1,
#    'conclude': 1,
#    'put:VMOD:shame': 1,
#    ' this': 1,
#    ' GAM': 1,
#    'bus': 1,
#    'your character': 1,
#    ';) ': 1,
#    '! ': 1,
#    'cluster106': 1,
#    'kill your': 1,
#    'is why': 1,
#    'skill to': 1,
#    'cook for': 1,
#    'g the': 1,
#    'and try': 1,
#    'most elaborate': 1,
#    'praise': 1,
#    'ress ': 1,
#    'it .': 1,
#    'cluster1674': 1,
#    'a meter': 1,
#    "'": 1,
#    'ame': 1,
#    'can keep': 1,
#    'like very': 1,
#    'pay': 1,
#    'unli': 1,
#    'o s': 1,
#    'for me': 1,
#    'servers .': 1,
#    ' PL': 1,
#    'shots more': 1,
#    'defend': 1,
#    'tend to': 1,
#    'E A': 1,
#    'cluster1492': 1,
#    'have:ROOT:fortress': 1,
#    'cluster3690': 1,
#    ...},
#   'y': 3},
#  'db_data': None}

# %%
len(normalized_ids_data_dict)
# Out:
# 1479

# %%
# Let's create a cursor over all Team Fortress 2 documents
game = 'Team_Fortress_2'
partition = 'test'
cursor = reviewdb.find({'game': game})

# %%
# How many samples are there for Team Fortress 2 (all partitions combined)?
cursor.count()
# Out:
# 3757

# %%
# Example document
sample = next(cursor)
sample
# Out:
# {'_id': ObjectId('55c58c39c134cf069a422b0e'),
#  'achievement_progress': {'num_achievements_attained': 0,
#   'num_achievements_percentage': 0.0,
#   'num_achievements_possible': 28},
#  'appid': '440',
#  'bin_factor': 1.5,
#  'bin_ranges': [[0.0, 845.5],
#   [845.6, 2113.8],
#   [2113.9, 4016.3],
#   [4016.4, 6870.0]],
#  'binarized': True,
#  'date_posted': 'Jun 29, 2014, 10:32PM',
#  'date_updated': None,
#  'features': '{" sp": 1, "another": 1, "at-b": 1, "d spe": 1, "d a": 1, "hour:OBJ:100+": 1, "ting": 1, " anot": 1, "nd": 1, "d da": 1, "mu": 1, "in": 1, "urs ": 1, " simu": 1, "ed ": 1, "er 1": 1, " hou": 1, "ato": 1, "ulato": 1, "simul": 1, "g s": 1, "hat-b": 1, "ther ": 1, "other": 1, " pl": 1, "100+": 1, "s pla": 1, "nd a": 1, "ng ": 1, "cluster11242": 1, "or ": 1, "ati": 1, " wo": 1, "ur": 1, "ould": 1, "ay": 1, "0+": 1, "anoth": 1, "zeroes_repvecs": 3, "d ano": 1, "ano": 1, "er ": 1, "rs pl": 1, "+ ": 1, "nd an": 1, "or": 1, "da": 1, "ot": 1, "r wo": 1, "spe": 1, "cluster28650": 1, "spend:VC:hour": 1, "00": 1, " hat": 1, "rs ": 1, "ting ": 1, " p": 1, "as": 1, "bas": 1, "dat": 1, " w": 1, " dati": 1, "end ": 1, "spend another": 1, "ing": 1, " s": 1, "dating simulator": 1, "or wo": 1, "mulat": 1, "tor ": 1, "mula": 1, "a+ hat-based": 1, "the": 1, "ing ": 1, "cluster5898": 1, "anot": 1, "her 1": 1, "simu": 1, "base": 1, "layin": 1, "A+ ha": 1, "r w": 1, "would spend": 1, "ld sp": 1, "sim": 1, "sp": 1, "ng": 1, " spe": 1, ".": 1, "00+": 1, "wou": 1, "datin": 1, "A+ ": 1, "uld ": 1, "spend:VC:play": 1, "urs p": 1, "s ": 1, "+ h": 1, "cluster1657": 1, "pen": 1, "at-": 1, "pend": 1, "hat-based dating": 1, "ing s": 1, "simulator would": 1, "t-ba": 1, "ng.": 1, "cluster1978": 1, "mean_cos_sim": 0.23777243494987488, "would": 1, "oth": 1, "d dat": 1, "hours": 1, " 1": 1, "to": 1, "d s": 1, " 10": 1, "ator ": 1, "hour": 1, "simulator:SUB:a+": 1, " sim": 1, "her": 1, "ha": 1, "based": 1, "-ba": 1, "dati": 1, "end a": 1, "hours playing": 1, "r 10": 1, "nd ": 1, "ing.": 1, "pl": 1, " an": 1, "hour:OBJ:another": 1, "ld": 1, "th": 1, "00+ h": 1, "yin": 1, "ther": 1, "an": 1, "spend": 1, "ba": 1, "tin": 1, "ng s": 1, "uld": 1, "tor": 1, "oul": 1, "woul": 1, "imul": 1, "yi": 1, "d an": 1, "10": 1, "ul": 1, "layi": 1, "lator": 1, "end": 1, " d": 1, "-base": 1, " ano": 1, "her ": 1, " play": 1, "r wou": 1, "playi": 1, "lato": 1, "spen": 1, "cluster0": 1, "ased ": 1, "ayi": 1, "ed d": 1, "playing .": 1, "simulator:SUB:hat-based": 1, "t-bas": 1, "pla": 1, "sed d": 1, " hat-": 1, "sed ": 1, "ed da": 1, "s pl": 1, "lay": 1, "aying": 1, "sed": 1, "mul": 1, "would:ROOT:simulator": 1, "dating": 1, " ha": 1, "g.": 1, "nothe": 1, "g ": 1, "uld s": 1, "-b": 1, "-bas": 1, "er": 1, "ator": 1, "ti": 1, " a": 1, "rs p": 1, "en": 1, " dat": 1, "ating": 1, "ase": 1, "se": 1, "playing": 1, "simulator:SUB:date": 1, "he": 1, "ed": 1, "ayin": 1, " si": 1, "100": 1, "00+ ": 1, "ours": 1, "simulator": 1, "urs": 1, "r ": 1, "ould ": 1, " hour": 1, "+ ha": 1, "A+ h": 1, "t-": 1, " 100+": 1, "ulat": 1, "r 100": 1, "ying": 1, "hat-": 1, "ula": 1, "cluster957": 1, "+ ho": 1, "cluster16170": 1, "ld s": 1, "at-ba": 1, "rs": 1, "imu": 1, " ho": 1, "0+ ho": 1, "pend ": 1, "ng si": 1, "atin": 1, "would:ROOT:spend": 1, "ou": 1, "s p": 1, "A+": 1, "at": 1, "imula": 1, "+ hat": 1, "noth": 1, "g si": 1, "no": 1, "pe": 1, "ho": 1, "wo": 1, "not": 1, " woul": 1, "ours ": 1, "cluster8": 1, "+ hou": 1, "er 10": 1, "lat": 1, "ying.": 1, "t-b": 1, "othe": 1, " wou": 1, " spen": 1, "100+ ": 1, "or w": 1, " 100": 1, "d d": 1, "0+ ": 1, "0+ h": 1, "a+": 1, "im": 1, "ld ": 1, "another 100+": 1, "la": 1, "play": 1, " h": 1, "7": 1, "tor w": 1, "g sim": 1, "d sp": 1, "d ": 1, "hat": 1, "hou": 1, "ased": 1, "si": 1, "r 1": 1, "our": 1, "100+ hours": 1, " pla": 1, " da": 1, "hat-based": 1}',
#  'found_helpful_percentage': 1.0,
#  'friend_player_level': 15,
#  'game': 'Team_Fortress_2',
#  'nbins': 4,
#  'num_badges': 8,
#  'num_comments': 0,
#  'num_found_funny': 0,
#  'num_found_helpful': 2,
#  'num_found_unhelpful': 0,
#  'num_friends': 56,
#  'num_games_owned': 42,
#  'num_groups': 2,
#  'num_guides': 0,
#  'num_reviews': 1,
#  'num_screenshots': 7,
#  'num_voted_helpfulness': 2,
#  'num_workshop_items': 0,
#  'orig_url': 'http://steamcommunity.com/app/440/homecontent/?userreviewsoffset=4090&p=1&itemspage=410&screenshotspage=410&videospage=410&artpage=410&allguidepage=410&webguidepage=410&integratedguidepage=410&discussionspage=410&appid=440&appHubSubSection=10&appHubSubSection=10&l=english&browsefilter=toprated&filterLanguage=default&searchText=&forceanon=1',
#  'partition': 'test',
#  'profile_url': 'http://steamcommunity.com/id/misskass',
#  'rating': 'Recommended',
#  'review': 'A+ hat-based dating simulator would spend another 100+ hours playing.',
#  'review_url': 'http://steamcommunity.com/id/misskass/recommended/440/',
#  'steam_id_number': 'misskass',
#  'total_game_hours': 98.8,
#  'total_game_hours_bin': 1,
#  'total_game_hours_last_two_weeks': 0.0,
#  'username': 'misskass'}

# %%
sample['_id']
# Out:
# ObjectId('55c58c39c134cf069a422b0e')

# %%
str(abs(hash(str(sample['_id']))))
# Out:
# '1909195635508261055'

# %%
str(abs(hash(str(sample['_id']))))
# Out:
# '1909195635508261055'

# %%
# Let's iterate through the documents
not_found = []
for sample in cursor:
    _id = sample.get('_id')
    normalized_id = normalize_id(_id)
    if normalized_ids_data_dict.get(normalize_id):
        _data = dict(normalized_ids_data_dict[normalized_id])
        _data['db_data'] = dict(sample)
        normalized_ids_data_dict[normalized_id] = _data
    else:
        not_found.append((_id,
                          normalized_id))

# %%
not_found[:100]
# Out:
# [(ObjectId('55c58c39c134cf069a422b0e'), '1909195635508261055'),
#  (ObjectId('55c58c39c134cf069a4224e4'), '4633408371632359236'),
#  (ObjectId('55c58c38c134cf069a42223c'), '7630855974652181728'),
#  (ObjectId('55c58c38c134cf069a421ef6'), '1664353644504832285'),
#  (ObjectId('55c58c38c134cf069a421ef8'), '5720264909250722215'),
#  (ObjectId('55c58c38c134cf069a421f96'), '2045903905335424682'),
#  (ObjectId('55c58c39c134cf069a422b10'), '210350313556682255'),
#  (ObjectId('55c58c39c134cf069a422b12'), '1489121607281958827'),
#  (ObjectId('55c58c38c134cf069a422261'), '5819740434479488346'),
#  (ObjectId('55c58c38c134cf069a422264'), '8708389093215260765'),
#  (ObjectId('55c58c39c134cf069a422adf'), '7303174278720180454'),
#  (ObjectId('55c58c39c134cf069a4224e3'), '5789688444339064255'),
#  (ObjectId('55c58c39c134cf069a422648'), '6710538697226985439'),
#  (ObjectId('55c58c39c134cf069a4226b1'), '2503376310676942627'),
#  (ObjectId('55c58c39c134cf069a4226b2'), '6876445705561660817'),
#  (ObjectId('55c58c39c134cf069a4226b3'), '4611051588272100834'),
#  (ObjectId('55c58c39c134cf069a4226b4'), '5221949318229198649'),
#  (ObjectId('55c58c39c134cf069a4226b5'), '1488545499517801236'),
#  (ObjectId('55c58c39c134cf069a4226b6'), '148771714443811303'),
#  (ObjectId('55c58c39c134cf069a4226b7'), '3346001637629310600'),
#  (ObjectId('55c58c39c134cf069a4226b8'), '1392732990308605212'),
#  (ObjectId('55c58c39c134cf069a4226b9'), '4216889252381358026'),
#  (ObjectId('55c58c39c134cf069a4226ba'), '2687003561060995666'),
#  (ObjectId('55c58c39c134cf069a4226bb'), '5777329373643772012'),
#  (ObjectId('55c58c39c134cf069a4226bc'), '5742341330406912458'),
#  (ObjectId('55c58c39c134cf069a4226bd'), '8629210772581485232'),
#  (ObjectId('55c58c39c134cf069a4226be'), '4258959784244661363'),
#  (ObjectId('55c58c39c134cf069a4226bf'), '3446608269530225063'),
#  (ObjectId('55c58c39c134cf069a4226c0'), '2585621578137418026'),
#  (ObjectId('55c58c39c134cf069a4226c1'), '1802152735283085296'),
#  (ObjectId('55c58c39c134cf069a4226c2'), '4796534167359119376'),
#  (ObjectId('55c58c39c134cf069a4226c3'), '8496691119908220313'),
#  (ObjectId('55c58c39c134cf069a4226c4'), '7332874435630275016'),
#  (ObjectId('55c58c39c134cf069a4226c5'), '1716078069899689406'),
#  (ObjectId('55c58c39c134cf069a4226c6'), '208362015528740254'),
#  (ObjectId('55c58c39c134cf069a4226c7'), '7205313246461849653'),
#  (ObjectId('55c58c39c134cf069a4226c8'), '1622882060428736211'),
#  (ObjectId('55c58c39c134cf069a4226c9'), '6280848591215939616'),
#  (ObjectId('55c58c39c134cf069a4226ca'), '7071947568578629946'),
#  (ObjectId('55c58c39c134cf069a4226cb'), '2003068363106397929'),
#  (ObjectId('55c58c39c134cf069a4226cc'), '6716164502814475381'),
#  (ObjectId('55c58c39c134cf069a4226cd'), '3439764665124862786'),
#  (ObjectId('55c58c39c134cf069a4226ce'), '7855339143029784437'),
#  (ObjectId('55c58c39c134cf069a4226cf'), '5085383361687474499'),
#  (ObjectId('55c58c39c134cf069a4226d0'), '7539271633419667722'),
#  (ObjectId('55c58c39c134cf069a4226d1'), '5839094185487716586'),
#  (ObjectId('55c58c39c134cf069a4226d2'), '1321121210142390115'),
#  (ObjectId('55c58c39c134cf069a4226d3'), '6539257260534963577'),
#  (ObjectId('55c58c39c134cf069a4226d4'), '724002817029426996'),
#  (ObjectId('55c58c39c134cf069a4226d5'), '1809160737206759054'),
#  (ObjectId('55c58c39c134cf069a4226d6'), '6299305534406425267'),
#  (ObjectId('55c58c39c134cf069a4226d7'), '5653463783680362856'),
#  (ObjectId('55c58c39c134cf069a4226d8'), '5478295597227602522'),
#  (ObjectId('55c58c39c134cf069a4226d9'), '8349099066160097084'),
#  (ObjectId('55c58c39c134cf069a4226da'), '7451064222195235010'),
#  (ObjectId('55c58c39c134cf069a4226db'), '4249590128229318075'),
#  (ObjectId('55c58c39c134cf069a4226dc'), '1762665672785122360'),
#  (ObjectId('55c58c39c134cf069a4226dd'), '1981928781946859607'),
#  (ObjectId('55c58c39c134cf069a4226de'), '7438246426993958971'),
#  (ObjectId('55c58c39c134cf069a4226df'), '4221530377079391690'),
#  (ObjectId('55c58c39c134cf069a4226e0'), '922712247129336023'),
#  (ObjectId('55c58c39c134cf069a4226e1'), '1600472988124629380'),
#  (ObjectId('55c58c39c134cf069a4226e2'), '4826382721253689087'),
#  (ObjectId('55c58c39c134cf069a4226e3'), '1313363406541155653'),
#  (ObjectId('55c58c39c134cf069a4226e4'), '7769983981864105553'),
#  (ObjectId('55c58c39c134cf069a4226e5'), '5723764843326163068'),
#  (ObjectId('55c58c39c134cf069a4226e6'), '5430339808138743418'),
#  (ObjectId('55c58c39c134cf069a4226e7'), '1124313152262569561'),
#  (ObjectId('55c58c39c134cf069a4226e8'), '8675080892845019700'),
#  (ObjectId('55c58c39c134cf069a4226e9'), '6048493544434548060'),
#  (ObjectId('55c58c39c134cf069a4226ea'), '2520790000392676673'),
#  (ObjectId('55c58c39c134cf069a4226eb'), '1054396530320803596'),
#  (ObjectId('55c58c39c134cf069a4226ec'), '6002750156241003411'),
#  (ObjectId('55c58c39c134cf069a4226ed'), '4674134143291868917'),
#  (ObjectId('55c58c39c134cf069a4226ee'), '6582771894285500752'),
#  (ObjectId('55c58c39c134cf069a4226ef'), '8958639196873789991'),
#  (ObjectId('55c58c39c134cf069a4226f0'), '2544269528885884681'),
#  (ObjectId('55c58c39c134cf069a4226f1'), '5136170530799249595'),
#  (ObjectId('55c58c39c134cf069a4226f2'), '4103378856243521159'),
#  (ObjectId('55c58c39c134cf069a4226f3'), '730646647010069299'),
#  (ObjectId('55c58c39c134cf069a4226f4'), '3245961021192667801'),
#  (ObjectId('55c58c39c134cf069a4226f5'), '8388938102070453678'),
#  (ObjectId('55c58c39c134cf069a4226f6'), '2648525329129790831'),
#  (ObjectId('55c58c39c134cf069a4226f7'), '1718461690557587340'),
#  (ObjectId('55c58c39c134cf069a4226f8'), '745718600949528957'),
#  (ObjectId('55c58c39c134cf069a4226f9'), '7611942494490672866'),
#  (ObjectId('55c58c39c134cf069a4226fa'), '2801123585549836312'),
#  (ObjectId('55c58c39c134cf069a4226fb'), '162024718152226373'),
#  (ObjectId('55c58c39c134cf069a4226fc'), '9158641283961572196'),
#  (ObjectId('55c58c39c134cf069a4226fd'), '4437493622698276612'),
#  (ObjectId('55c58c39c134cf069a4226fe'), '2307389557010878463'),
#  (ObjectId('55c58c39c134cf069a4226ff'), '1143804801424916338'),
#  (ObjectId('55c58c39c134cf069a422700'), '3839829333395743419'),
#  (ObjectId('55c58c39c134cf069a422701'), '5626321293360453840'),
#  (ObjectId('55c58c39c134cf069a422702'), '834028591060127049'),
#  (ObjectId('55c58c39c134cf069a422703'), '3490106049565522406'),
#  (ObjectId('55c58c39c134cf069a422704'), '8535216112840012645'),
#  (ObjectId('55c58c39c134cf069a422705'), '4561928712675129234'),
#  (ObjectId('55c58c39c134cf069a422706'), '754693939010209833'),
#  (ObjectId('55c58c39c134cf069a422707'), '4521548605350220843')]
